# %%
from QIP import *

# %%
def grovers(goal_state, num_iterations):
    num_qubits = len(goal_state)+1
    circuit = QCircuit(num_qubits,allow_empty_systems=True)
    
    # h on all except ancilla
    #for qubit in range(num_qubits-1):
    #    circuit.h(qubit) 
        
    # NOT on ancilla    
    #circuit.x(num_qubits-1)
    
    # h on all except ancilla using one single gate
    op = 1.
    for q in range(num_qubits-1):
        op = np.kron(op,h)
    circuit.apply_to_circuit(np.kron(op,x))
    # grover iteration
    for grover_iteration in range(num_iterations):
        # flip ancilla controlled by bitstring of goal state
        circuit.apply_to_circuit(arbitrary_U(x,num_qubits,[num_qubits-1],control_bitstring=goal_state))
        
        # h on all except ancilla
        # for qubit in range(num_qubits-1):
        #     circuit.h(qubit)
        circuit.h_on_set(list(range(num_qubits-1))) 

        # phase flip ancilla if state is all zeros
        circuit.apply_to_circuit(arbitrary_U(z,num_qubits,[num_qubits-1],control_bitstring='0'*len(goal_state)))

        # h on all except ancilla
        # for qubit in range(num_qubits-1):
        #     circuit.h(qubit)
        circuit.h_on_set(list(range(num_qubits-1))) 
    return circuit

# %% [markdown]
# Grover's algorithm on $4+1$ qubits

# %%
grovers_circuit_4_bits = grovers('1101',3)
grovers_circuit_4_bits.save_to_file("grovers-4.pkl")

# %%
bitstrings_dict_from_vector(grovers_circuit_4_bits.statevector)
# Out:
# {'00001': -0.08154296874999997,
#  '00011': -0.08154296874999997,
#  '00101': -0.08154296874999994,
#  '00111': -0.08154296874999994,
#  '01001': -0.08154296875,
#  '01010': -2.7755575615628914e-17,
#  '01011': -0.08154296875000006,
#  '01101': -0.08154296875,
#  '01111': -0.08154296875,
#  '10001': -0.08154296874999997,
#  '10011': -0.08154296874999997,
#  '10101': -0.08154296874999994,
#  '10111': -0.08154296874999994,
#  '11001': -0.08154296875000006,
#  '11010': 0.6289062499999999,
#  '11011': -0.71044921875,
#  '11101': -0.08154296875000003,
#  '11111': -0.08154296874999997}

# %%
grovers_circuit_4_bits.plot_saturations(savefiles=True,folder="grovers-4/")

# %% [markdown]
# Grover's algorithm on 5 qubits

# %%
grovers_circuit_5_bits = grovers('11010',int(2**4))

# %%
grovers_circuit_5_bits.plot_saturations(savefiles=True,folder="grovers-5/")

# %% [markdown]
# Grover's algorithm on 6 qubits

# %%
grovers_circuit_6_bits = grovers('110101',int(2**4))

# %%
plt.plot(grovers_circuit_4_bits.ssa["avg_saturation"],label="4+1 qubits")
plt.plot(grovers_circuit_5_bits.ssa["avg_saturation"],label="5+1 qubits")
plt.plot(grovers_circuit_6_bits.ssa["avg_saturation"],label="6+1 qubits")
plt.title("Grover's Algorithm SSA")
plt.ylabel("Average saturation (bits)")
plt.xlabel("Circuit Depth")
plt.legend(loc="lower right")
plt.savefig("grovers-ssa.jpg", dpi=300)

# %%
plt.plot(grovers_circuit_4_bits.mmi["avg_saturation"],label="4+1 qubits")
plt.plot(grovers_circuit_5_bits.mmi["avg_saturation"],label="5+1 qubits")
plt.plot(grovers_circuit_6_bits.mmi["avg_saturation"],label="6+1 qubits")
plt.title("Grover's Algorithm MMI")
plt.ylabel("Average  saturation (bits)")
plt.xlabel("Circuit Depth")
plt.legend(loc="lower right")
plt.savefig("grovers-mmi.jpg", dpi=300)

# %%
plt.plot(grovers_circuit_4_bits.mmi["avg_fail_saturation"],label="4+1 qubits")
plt.plot(grovers_circuit_5_bits.mmi["avg_fail_saturation"],label="5+1 qubits")
plt.plot(grovers_circuit_6_bits.mmi["avg_fail_saturation"],label="6+1 qubits")
plt.title("Grover's Algorithm MMI Failure")
plt.ylabel("Average failure saturation (bits)")
plt.xlabel("Circuit Depth")
plt.legend(loc="lower right")
plt.savefig("grovers-mmi-fail.jpg", dpi=300)

# %%
plt.plot(grovers_circuit_4_bits.mmi["percent_fail"],label="4+1 qubits")
plt.plot(grovers_circuit_5_bits.mmi["percent_fail"],label="5+1 qubits")
plt.plot(grovers_circuit_6_bits.mmi["percent_fail"],label="6+1 qubits")
plt.title("Grover's Algorithm MMI Failure Ratio")
plt.xlabel("Circuit Depth")
plt.legend()
plt.savefig("grovers-mmi-failratio.jpg", dpi=300)

# %%
plt.plot(grovers_circuit_4_bits.ing["avg_saturation"],label="4+1 qubits")
plt.plot(grovers_circuit_5_bits.ing["avg_saturation"],label="5+1 qubits")
plt.plot(grovers_circuit_6_bits.ing["avg_saturation"],label="6+1 qubits")
plt.title("Grover's Algorithm Ingelton's Inequality")
plt.ylabel("Average saturation (bits)")
plt.xlabel("Circuit Depth")
plt.legend(loc="lower right")
plt.savefig("grovers-ing.jpg", dpi=300)

# %%
print(grovers_circuit_4_bits.mmi["percent_fail"])
# Out:
# [0.0, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802, 0.21390374331550802]

# %%
print(grovers_circuit_5_bits.mmi["percent_fail"])
# Out:
# [0.0, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365, 0.36363636363636365]

# %%
print(grovers_circuit_6_bits.mmi["percent_fail"])
# Out:
# [0.0, 0.0, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264, 0.5008944543828264]

# %%
grovers_circuit_6_bits.plot_saturations(savefiles=True,folder="grovers-6/")

# %%
def qft(circuit_size,input_vector=None):
        
    if input_vector is not None:
        circuit = QCircuit(circuit_size,initial_state=input_vector)
    else: circuit = QCircuit(circuit_size)
    # Begin the QFT
    for i in range(circuit_size):
        circuit.h(i)
        
        for k in range(2,circuit_size+1-i):
            R_k = np.array([[1.,0.],[0.,np.exp(1.j*2*np.pi/2**k)]])
            circuit.apply_to_circuit(arbitrary_U(R_k,circuit_size,[i],controls=[i+k-1]))
    circuit.reverse_bits()
    return circuit

# %% [markdown]
# Interesting note: The DFT matrix using $\omega=e^{2\pi i/8}=\sqrt{i}$ as in Nielsen and Chuang will give the fourier transform but in the wrong order, but using $e^{-2\pi i/8}$ gives the correct order, however this is not what the QFT does. One would need to do a swap operation reversing the second to the last elements in the statevector.

# %%
vec=np.random.random(2**3)+np.random.random(2**3)*1j
vec=vec/np.linalg.norm(vec)

k = np.arange(8)
W_plus = np.exp(2j * np.pi * k[:, None] * k / 8)/8**.5
W_minus = np.exp(-2j * np.pi * k[:, None] * k / 8)/8**.5
fft = np.round(np.fft.fft(vec)/8**.5,4)
qftc=np.round(qft(3,vec).statevector,4)
print("x: \t\t\t"+"DFT+(x): \t\t"+"DFT-(x): \t\t"+ "FFT(x): \t\t","QFT(x): ")
for i in range(8):
    print(np.round(vec[i],4),"\t",np.round((W_plus@vec)[i],4),"\t",np.round((W_minus@vec)[i],4),"\t",fft[i],"\t",qftc[i])
# Out:
# x: 			DFT+(x): 		DFT-(x): 		FFT(x): 		 QFT(x):
# (0.3245+0.0108j) 	 (0.6087+0.5962j) 	 (0.6087+0.5962j) 	 (0.6087+0.5962j) 	 (0.6087+0.5962j)
# (0.0295+0.3456j) 	 (-0.0608-0.1651j) 	 (0.0183+0.0587j) 	 (0.0183+0.0587j) 	 (-0.0608-0.1651j)
# (0.0828+0.078j) 	 (0.2501-0.0343j) 	 (0.0737+0.1497j) 	 (0.0737+0.1497j) 	 (0.2501-0.0343j)
# (0.2078+0.3199j) 	 (-0.0589-0.3032j) 	 (0.1129-0.1039j) 	 (0.1129-0.1039j) 	 (-0.0589-0.3032j)
# (0.3165+0.3739j) 	 (-0.0261-0.1675j) 	 (-0.0261-0.1675j) 	 (-0.0261-0.1675j) 	 (-0.0261-0.1675j)
# (0.2893+0.0698j) 	 (0.1129-0.1039j) 	 (-0.0589-0.3032j) 	 (-0.0589-0.3032j) 	 (0.1129-0.1039j)
# (0.1002+0.1435j) 	 (0.0737+0.1497j) 	 (0.2501-0.0343j) 	 (0.2501-0.0343j) 	 (0.0737+0.1497j)
# (0.3711+0.3448j) 	 (0.0183+0.0587j) 	 (-0.0608-0.1651j) 	 (-0.0608-0.1651j) 	 (0.0183+0.0587j)

# %%
circs = []
for n in (5,6,7):
    vec=np.random.random(2**n)+np.random.random(2**n)*1j
    vec=vec/np.linalg.norm(vec)
    qft_circuit = qft(n,vec)
    circs.append(qft_circuit)

# %%
c = 5
for circ in circs:
    plt.plot(circ.mmi["avg_fail_saturation"],label=str(c)+" qubits")
    c = c+1

plt.title("QFT MMI Failure")
plt.ylabel("Average failure saturation (bits)")
plt.xlabel("Failing states reached")
plt.legend()
plt.savefig("qft-mmi-fail-4.jpg", dpi=300)

# %%
c = 5
for circ in circs:
    plt.plot(circ.mmi["avg_saturation"],label=str(c)+" qubits")
    c = c+1

plt.title("QFT MMI")
plt.ylabel("Average saturation (bits)")
plt.xlabel("Gates Applied")
plt.legend()
plt.savefig("qft-mmi-4.jpg", dpi=300)

# %%
c = 5
for circ in circs:
    plt.plot(circ.ing["avg_saturation"],label=str(c)+" qubits")
    c = c+1

plt.title("QFT Ingelton's Inequality")
plt.ylabel("Average saturation (bits)")
plt.xlabel("Gates Applied")
plt.legend()
plt.savefig("qft-ing-4.jpg", dpi=300)

# %%
vec=np.random.random(2**6)+np.random.random(2**6)*1j
vec=vec/np.linalg.norm(vec)
qft_circuit = qft(6,vec)
qft_circuit.plot_saturations(savefiles=True,folder="qft-6/")

# %%
def qft_inverse(circuit_size,input_vector = None):
    if input_vector is not None:
        circuit = QCircuit(circuit_size,initial_state=input_vector)
    else: circuit = QCircuit(circuit_size)
    
    # Begin the inverse QFT
    
    for i in range(circuit_size):
        circuit.h(i)
        
        # Controlled reverse-phase on each qubit 
        for k in range(2,circuit_size-i+1):
            R_k = np.array([[1.,0.],[0.,np.exp(-1.j*2*np.pi/2**k)]])
            circuit.apply_to_circuit(arbitrary_U(R_k,circuit_size,targets=[i],controls=[i+k-1]))
    circuit.reverse_bits()

    return circuit

# %%
qft_i_circuit_6 = qft_inverse(6,vec)

# %%
qft_i_circuit_6.plot_saturations(savefiles=True,folder="qft-i-6/")

# %%
def qpe(U,num_auxiliary_bits,eigvec):
    
    m = int(np.log2(np.shape(U)[0]))
    num_qubits = num_auxiliary_bits + m
    circuit = QCircuit(num_qubits,initial_state=np.kron(bitstrings_to_vector('0'*num_auxiliary_bits),eigvec))
    circuit.h_on_set(list(range(num_auxiliary_bits)))
    
    for k in range(num_auxiliary_bits):
        circuit.apply_to_circuit(arbitrary_U(np.linalg.matrix_power(U,2**k),num_qubits,list(range(num_auxiliary_bits,num_qubits)),controls=[num_auxiliary_bits-1-k]))
    
    # inverse qft on auxiliary bits
    for i in range(num_auxiliary_bits):
        circuit.h(i)
        # Controlled reverse-phase on each qubit 
        for k in range(2,num_auxiliary_bits-i+1):
            R_k = np.array([[1.,0.],[0.,np.exp(-1.j*2*np.pi/2**k)]])
            circuit.apply_to_circuit(arbitrary_U(R_k,num_qubits,targets=[i],controls=[i+k-1]))
    # reverse bits 
    if num_auxiliary_bits == 2:
        circuit.apply_to_circuit(arbitrary_swap(num_qubits,[0],[1]))
    if num_auxiliary_bits == 3:
        circuit.apply_to_circuit(arbitrary_swap(num_qubits,[0],[2]))
    if num_auxiliary_bits > 3:
        circuit.apply_to_circuit(arbitrary_swap(num_qubits,list(range(num_auxiliary_bits))[:int(num_auxiliary_bits/2)],list(range(num_auxiliary_bits))[int(np.ceil(num_auxiliary_bits/2)):]))
    return circuit

# %%
def qpe_incomplete(U,num_auxiliary_bits,eigvec):
    
    m = int(np.log2(np.shape(U)[0]))
    num_qubits = num_auxiliary_bits + m
    circuit = QCircuit(num_qubits,initial_state=np.kron(bitstrings_to_vector('0'*num_auxiliary_bits),eigvec),pure_state=False)
    circuit.h_on_set(list(range(num_auxiliary_bits)))
    for k in [0,1]:
        circuit.apply_to_circuit(arbitrary_U(U**(2**k),num_qubits,list(range(num_auxiliary_bits,num_qubits)),controls=[num_auxiliary_bits-1-k]))
    return circuit

# %%
def qr_haar(N):
    """Generate a Haar-random matrix using the QR decomposition."""
    # Step 1
    A, B = np.random.normal(size=(N, N)), np.random.normal(size=(N, N))
    Z = A + 1j * B

    # Step 2
    Q, R = np.linalg.qr(Z)

    # Step 3
    Lambda = np.diag([R[i, i] / np.abs(R[i, i]) for i in range(N)])

    # Step 4
    return np.dot(Q, Lambda)

# %%
rand_U = qr_haar(4)
eigvals, eigvecs = np.linalg.eig(rand_U)
eigval = eigvals[0]
num_auxiliary_bits = 3
m = int(np.log2(np.shape(rand_U)[0]))
num_qubits = num_auxiliary_bits + m
initial_state=np.kron(bitstrings_to_vector('0'*num_auxiliary_bits),eigvecs[:,0])
h_on_aux = 1.
for i in range(num_auxiliary_bits):
    h_on_aux = np.kron(h_on_aux,h)
for j in range(m):
    h_on_aux = np.kron(h_on_aux,np.eye(2))
first_CU = arbitrary_U(rand_U,num_qubits,targets=list(range(num_auxiliary_bits,num_qubits)),controls=[num_auxiliary_bits-1])
second_CU = arbitrary_U(rand_U**2,num_qubits,targets=list(range(num_auxiliary_bits,num_qubits)),controls=[num_auxiliary_bits-2])

state1 = QCircuit(num_qubits)
state1.density_matrix=np.outer(initial_state,initial_state.conj())
state1.subsystem_analysis()
print(state1.mmi)

state_after_h = h_on_aux@initial_state
state2 = QCircuit(num_qubits)
state2.density_matrix=np.outer(state_after_h,state_after_h.conj())
state2.subsystem_analysis()
print(state2.mmi)

state_after_CU = first_CU@state_after_h
state3 = QCircuit(num_qubits)
state3.density_matrix=np.outer(state_after_CU,state_after_CU.conj())
state3.subsystem_analysis()
print(state3.mmi)

state_after_CU2 = second_CU@state_after_CU
state4 = QCircuit(num_qubits)
state4.density_matrix=np.outer(state_after_CU2,state_after_CU2.conj())
state4.subsystem_analysis()
print(state4.mmi)
# Out:
# {'avg_saturation': [1.6543657682964026e-18], 'percent_fail': [0.0], 'avg_fail_saturation': []}
# {'avg_saturation': [-3.156339667298323e-17], 'percent_fail': [0.0], 'avg_fail_saturation': []}
# {'avg_saturation': [-1.4263504804680408e-16], 'percent_fail': [0.0], 'avg_fail_saturation': []}
# {'avg_saturation': [-0.05654390176507096], 'percent_fail': [1.0], 'avg_fail_saturation': [0.05654390176507096]}

# %%
rand_U = qr_haar(4)
eigvals, eigvecs = np.linalg.eig(rand_U)
eigval = eigvals[0]
print(eigval)
circs = []
qpe_circuit = qpe(rand_U,3,eigvecs[:,0])
# Out:
# (0.9892591546890253+0.14617224382199107j)

# %%
import csv
decimal_places = 14
keys = sorted(set(key for d in qpe_circuit.entropies for key in d.keys()))
with open("qpe_entropies.csv", mode="w", newline="") as file:
    writer = csv.writer(file)
    
    # Write header
    header = ["System"] + [f"Depth {i + 1}" for i in range(len(qpe_circuit.entropies))]
    writer.writerow(header)
    
    # Write each row with the key and corresponding values from each dictionary
    for key in keys:
        row = [key] + [np.round(d.get(key, np.nan), decimals=decimal_places) for d in qpe_circuit.entropies]
        writer.writerow(row)

# %%
print(qpe_circuit.entropies[2])
# Out:
# {(): np.float64(-0.07965585839409105), (0, 1, 2, 3, 4): np.float64(-0.07965585839409105), (0,): np.float64(-0.07965585839409003), (1, 2, 3, 4): np.float64(-0.07965585839409003), (1,): np.float64(0.18531289302536796), (0, 2, 3, 4): np.float64(0.18531289302536796), (2,): np.float64(-0.07965585839409105), (0, 1, 3, 4): np.float64(-0.07965585839409105), (3,): np.float64(0.7347603878452408), (0, 1, 2, 4): np.float64(0.7347603878452408), (4,): np.float64(0.7195486455061217), (0, 1, 2, 3): np.float64(0.7195486455061217), (0, 1): np.float64(0.18531289302536805), (2, 3, 4): np.float64(0.18531289302536805), (0, 2): np.float64(-0.07965585839409105), (1, 3, 4): np.float64(-0.07965585839409105), (0, 3): np.float64(0.7347603878452408), (1, 2, 4): np.float64(0.7347603878452408), (0, 4): np.float64(0.7195486455061222), (1, 2, 3): np.float64(0.7195486455061222), (1, 2): np.float64(0.18531289302536832), (0, 3, 4): np.float64(0.18531289302536832), (1, 3): np.float64(0.7195486455061215), (0, 2, 4): np.float64(0.7195486455061215), (1, 4): np.float64(0.7347603878452404), (0, 2, 3): np.float64(0.7347603878452404), (2, 3): np.float64(0.7347603878452411), (0, 1, 4): np.float64(0.7347603878452411), (2, 4): np.float64(0.7195486455061227), (0, 1, 3): np.float64(0.7195486455061227), (3, 4): np.float64(0.1853128930253676), (0, 1, 2): np.float64(0.1853128930253676)}

# %%
rand_U = qr_haar(4)
eigvals, eigvecs = np.linalg.eig(rand_U)
eigval = eigvals[0]
print(eigval)
circs = []
for n in [3,4,5]:
    
    qpe_circuit = qpe(rand_U,n,eigvecs[:,0])
    circs.append(qpe_circuit)
# Out:
# (-0.7889947029372797-0.614399998972096j)

# %%
c = 3
for circ in circs:
    plt.plot(circ.mmi["avg_saturation"],label="2+"+str(c)+" qubits")
    c = c+1

plt.title("QPE MMI")
plt.ylabel("Average saturation (bits)")
plt.xlabel("Circuit Depth")
plt.legend(loc="lower right")
plt.savefig("qpe-mmi-2.jpg", dpi=300)

# %%
c = 5
for circ in circs:
    plt.plot(circ.mmi["avg_fail_saturation"],label="2+"+str(c)+" qubits")
    c = c+1

plt.title("QPE MMI Failure")
plt.ylabel("Average saturation (bits)")
plt.xlabel("Failing states reached")
plt.legend(loc="lower right")
plt.savefig("qpe-mmi-fail-2.jpg", dpi=300)

# %%
c = 5
for circ in circs:
    plt.plot(circ.ing["avg_saturation"],label=str(c)+" qubits")
    c = c+1

plt.title("QPE Ingleton's Inequality")
plt.ylabel("Average saturation (bits)")
plt.xlabel("Circuit Depth")
plt.legend(loc="lower right")
plt.savefig("qpe-ing-2.jpg", dpi=300)

# %%
c = 5
for circ in circs:
    plt.plot(circ.ing["avg_fail_saturation"],label=str(c)+" qubits")
    c = c+1

plt.title("QPE Ingleton's Inequality Failure")
plt.ylabel("Average saturation (bits)")
plt.xlabel("Failing states reached")
plt.legend(loc="lower right")
plt.savefig("qpe-ing-fail.jpg", dpi=300)

# %%
c = 5
for circ in circs:
    plt.plot(circ.mmi["avg_fail_saturation"],label=str(c)+" qubits")
    c = c+1

plt.title("QPE MMI Failure")
plt.ylabel("Average saturation (bits)")
plt.xlabel("Failing states reached")
plt.legend(loc="lower right")
plt.savefig("qpe-mmi-fail.jpg", dpi=300)

# %%
c = 5
for circ in circs:
    plt.plot(circ.ing["avg_saturation"],label=str(c)+" qubits")
    c = c+1

plt.title("QPE ING")
plt.ylabel("Average saturation (bits)")
plt.xlabel("Circuit Depth")
plt.legend(loc="lower right")
plt.savefig("qpe-ing.jpg", dpi=300)

# %%
U_size = 4
rand_U = qr_haar(U_size)
eigvals, eigvecs = np.linalg.eig(rand_U)
eigval = eigvals[0]
qpe_circuit = qpe(rand_U,3,eigvecs[:,0])

# %%
c = 5
for n in []
rand_U = qr_haar(U_size)
eigvals, eigvecs = np.linalg.eig(rand_U)
eigval = eigvals[0]
qpe_circuit = qpe(rand_U,3,eigvecs[:,0])
# Out:
#   Cell In[36], line 2
#     for n in []
#                ^
# SyntaxError: expected ':'

# %%
plt.plot(qpe_circuit.mmi["avg_saturation"])

plt.title("QPE MMI")
plt.ylabel("Average saturation (bits)")
plt.xlabel("Gates Applied")
plt.savefig("qpe-mmi.jpg", dpi=300)

# %%
plt.plot(qpe_circuit.mmi["avg_fail_saturation"])

plt.title("QPE MMI")
plt.ylabel("Average failure saturation (bits)")
plt.xlabel("Gates Applied")
plt.savefig("qpe-mmi.jpg", dpi=300)

# %%
plt.plot(qpe_circuit.mmi["avg_saturation"])

plt.title("QPE ING")
plt.ylabel("Average saturation (bits)")
plt.xlabel("Gates Applied")
plt.savefig("qpe-ing.jpg", dpi=300)

# %%
qpe_circuit.plot_saturations(savefiles=True,folder="qpe-7/")

# %% [markdown]
# Shor's

# %%
#Here we build the unitary needed for Shor's. In each step of phase estimation we must construct a new one
def order_finding_U(a,n,N):
    U = np.zeros((2**n,2**n))
    for k in range(2**n):
        if k < N: 
            transformed_k = (a*k)%N
        else: transformed_k = k
        row = np.array(1.)
        for bit in int_to_bitstring(transformed_k,n):
            row = np.kron(row,qubit_map[bit])
        U[k]=row
    return U.T

def order_finding(a,N):
    
    # number of qubits in second register
    n = int(np.ceil(np.log2(N)))
    
    # accuracy and number of qubits in first register
    m = 2*n+1
    
    # now execute the circuit
    circuit = QCircuit(m+n)
    
    # phase estimation step 
    
    # second register starts as |1>
    for q in range(m,n+m):
        circuit.x(q)
    
    # hadamard on all inputs
    for q in range(m):
        circuit.h(q)
    
    # controlled unitaries
    for k in range(m):
        circuit.apply_to_circuit(arbitrary_U(order_finding_U(a**(2**k),n,N),n+m,list(range(m,n+m)),controls=[n-1-k]))
    
    # inverse qft
    qfti_circuit = qft_inverse(m)
    circuit.apply_to_circuit(arbitrary_U(qfti_circuit.unitary,n+m,list(range(m))))
    return circuit

# %%
# my method for the partial trace, reorder the density matrix such that the bits to be traced out are at the end, then trace over second partition

def reorder_U(circuit_size,bits):
    """_summary_

    Args:
        circuit_size (int): number of bits in circuit
        bits (list): bits to move to the end

    Returns:
        ndarray: unitary permutation matrix which reorders the given bits
    """
    lgm = np.zeros((2**circuit_size,2**circuit_size))
    for bitint in range(2**circuit_size):
        bitstring = int_to_bitstring(bitint,circuit_size)
        transformed_bitstring = [bitstring[i] for i in range(len(bitstring)) if i not in bits] + [bitstring[i] for i in bits]
        row = np.array(1.)
        for bit in transformed_bitstring:
            row = np.kron(row,qubit_map[bit])
        lgm[bitint]=row
    return lgm.T

def partial_trace2(p,trace_out):
    """finds the reduced density matrix after tracing out the given indices

    Args:
        p (numpy.ndarray (2-d)): full density matrix
        trace_out (list): indices to trace out
    """
    d_b = len(trace_out)
    d_a = int(np.log2(np.shape(p)[0])) - d_b
    sum = 0
    for j in range(2**d_b):
        vec = np.zeros(2**d_b)
        vec[j]=1.
        vec.shape=(2**d_b,1)
        sum = sum + np.kron(np.eye(2**d_a),vec.conj().T)@reorder_U(d_b+d_a,trace_out).conj().T@p@reorder_U(d_b+d_a,trace_out)@np.kron(np.eye(2**d_a),vec)
        # sum = sum + np.kron(np.eye(2**d_a),vec.conj().T)@p@np.kron(np.eye(2**d_a),vec)
    return sum

# %%
def reorder_U(circuit_size,bits):
    """_summary_

    Args:
        circuit_size (int): number of bits in circuit
        bits (list): bits to move to the end

    Returns:
        ndarray: unitary permutation matrix which reorders the given bits
    """
    lgm = np.zeros((2**circuit_size,2**circuit_size))
    for bitint in range(2**circuit_size):
        bitstring = int_to_bitstring(bitint,circuit_size)
        transformed_bitstring = [bitstring[i] for i in bits] + [bitstring[i] for i in range(len(bitstring)) if i not in bits]
        row = np.array(1.)
        for bit in transformed_bitstring:
            row = np.kron(row,qubit_map[bit])
        lgm[bitint]=row
    return lgm.T

# %%
checkOperator(arbitrary_U(x,4,[3],controls=[0]))
# Out:
# 0000 -> 0000
# 0001 -> 0001
# 0010 -> 0010
# 0011 -> 0011
# 0100 -> 0100
# 0101 -> 0101
# 0110 -> 0110
# 0111 -> 0111
# 1000 -> 1001
# 1001 -> 1000
# 1010 -> 1011
# 1011 -> 1010
# 1100 -> 1101
# 1101 -> 1100
# 1110 -> 1111
# 1111 -> 1110

# %%
# a better method, turn the indices into bitstrings and sum over the bits given
def partial_trace(p,trace_out):
    """ finds the reduced density matrix given indices of bits to trace over

    Args:
        p (ndarray): density matrix to reduce
        trace_out (list): indices of bits to trace over

    Returns:
        ndarray: reduced density matrix after tracing out the given bits
    """
    d_b = len(trace_out)
    d_a = int(np.log2(np.shape(p)[0])) - d_b
    p_A = np.zeros((2**d_a,2**d_a),dtype=complex)
    for i in range(2**d_a):
        for k in range(2**d_a):
            for j in range(2**d_b):
                # build the bitstring of the indices, summing over only j
                bra_bitstring = ""
                ket_bitstring = ""
                ik_c = 0 # keep track of which binary digit of i,k 
                j_c = 0 # keep track of which binary digit of j, summed over
                for l in range(d_b+d_a):
                    if l in trace_out:
                        bra_bitstring = bra_bitstring + int_to_bitstring(j,d_b)[j_c]
                        ket_bitstring = ket_bitstring + int_to_bitstring(j,d_b)[j_c]
                        j_c = j_c + 1
                    else:
                        bra_bitstring = bra_bitstring + int_to_bitstring(i,d_a)[ik_c]
                        ket_bitstring = ket_bitstring + int_to_bitstring(k,d_a)[ik_c]
                        ik_c = ik_c + 1
                p_A[i][k] = p_A[i][k]+ p[int(bra_bitstring,2)][int(ket_bitstring,2)]
                # equivalent 'mathy' way but slower:
                # bra = bitstrings_to_vector(bra_bitstring)
                # bra.shape=(2**(d_b+d_a),1)
                # bra = bra.conj().T
                # ket = bitstrings_to_vector(ket_bitstring)
                # ket.shape=(2**(d_b+d_a),1)
                # p_A[i][k] = p_A[i][k]+bra@p@ket
    return p_A

# %%
partial_trace(U,[0])
# Out:
# array([[-0.07947533+0.01740418j,  0.24859421+0.27760346j,
#         -0.51507764+0.05932707j, -0.53367758+0.55245856j],
#        [ 0.66564568-0.53525363j, -0.25771319-0.08386336j,
#          0.57770121-0.45927752j,  0.63226509+0.75214147j],
#        [ 0.47813061-0.0157401j ,  0.49271198+0.06545887j,
#         -0.38056547+0.46541328j, -0.5375601 +0.00085667j],
#        [-0.09370206+0.26815878j, -0.22654193+0.37509979j,
#         -0.07399897-0.22547028j,  0.01855772+0.13406338j]])

# %%
partial_trace2(U,[0])
# Out:
# array([[-0.07947533+0.01740418j,  0.24859421+0.27760346j,
#         -0.51507764+0.05932707j, -0.53367758+0.55245856j],
#        [ 0.66564568-0.53525363j, -0.25771319-0.08386336j,
#          0.57770121-0.45927752j,  0.63226509+0.75214147j],
#        [ 0.47813061-0.0157401j ,  0.49271198+0.06545887j,
#         -0.38056547+0.46541328j, -0.5375601 +0.00085667j],
#        [-0.09370206+0.26815878j, -0.22654193+0.37509979j,
#         -0.07399897-0.22547028j,  0.01855772+0.13406338j]])

# %%
s=time.time()
partial_trace(matrix,[1,3])
e=time.time()
print(e-s)
# Out:
# 0.0015652179718017578

# %%
from QIP import *
n=6
W_state_dict = {}
for i in range(n):
    bitstring = "0"*n
    bitstring = bitstring[:i] + '1' + bitstring[i+1:]
    W_state_dict[bitstring] = 1/n**.5
W_state = QCircuit(6,initial_state=bitstrings_to_vector(W_state_dict))
W_state.subsysem_analysis()
print("W state: "+state_as_string(W_state_dict))
# prints an empty list if ingletons never fails
print("Average failure saturation of ingletons inequality: "+str(W_state.ing["avg_fail_saturation"]))
# Out:
# W state: 0.408|100000> + 0.408|010000> + 0.408|001000> + 0.408|000100> + 0.408|000010> + 0.408|000001>
# Saturation of ingletons inequality: []

# %%
state_dict = {}
state_dict['0000']=1/4
state_dict['1111']=1/4
state_dict['1010']=1/4
state_dict['1001']=1/4
ing_test = QCircuit(4,initial_state=bitstrings_to_vector(state_dict))
ing_test.subsysem_analysis()
print("Average failure saturation of ingletons inequality: "+str(ing_test.ing["avg_fail_saturation"]))
# Out:
# Average failure saturation of ingletons inequality: []

# %%
psi_dict = {}
psi_dict["0000"]=1/2**.5
psi_dict["1111"]=1/2**.5
psi_vec = bitstrings_to_vector(psi_dict)
psi_vec.shape=(2**4,1)
vec1 = bitstrings_to_vector("1010")
vec1.shape=(2**4,1)
vec2 = bitstrings_to_vector("1001")
vec2.shape=(2**4,1)
rho = 0.5*np.outer(psi_vec,psi_vec.conj().T)+0.25*np.outer(vec1,vec1.conj().T)+0.25*np.outer(vec2,vec2.conj().T)

ing_test = QCircuit(4)
ing_test.density_matrix=rho
ing_test.subsysem_analysis()
print("Average failure saturation of ingletons inequality: "+str(ing_test.ing["avg_fail_saturation"]))
# Out:
# Average failure saturation of ingletons inequality: []
